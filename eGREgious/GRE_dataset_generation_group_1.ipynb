# %% [markdown]
# # data

# %%
# Data with word, list of original sentences, paraphrases using synonyms, and context descriptions
data = {
    "abound": [
        ("Opportunities for adventure abound in this vibrant city.", "This vibrant city is teeming with opportunities for adventure.", "Urban Exploration"),
        ("Examples of kindness abound in her actions.", "Her actions are overflowing with examples of kindness.", "Behavioral Observation"),
        ("Wildflowers abound in the spring meadow.", "The spring meadow is brimming with wildflowers.", "Nature Description"),
        ("In the digital era, data security challenges abound.", "The digital era is fraught with data security challenges.", "Technology"),
        ("Culinary options abound in this multicultural neighborhood.", "This multicultural neighborhood is rich in culinary options.", "Cultural Diversity")
    ],
    "amorphous": [
        ("The artist created an amorphous sculpture.", "The artist created a formless sculpture.", "Art"),
        ("His plans for the weekend were amorphous.", "His weekend plans lacked a clear shape.", "Personal Planning"),
        ("Amorphous clouds drifted across the sky.", "Indistinct clouds drifted across the sky.", "Weather"),
        ("The committee's amorphous guidelines confused us.", "The committee's nebulous guidelines confused us.", "Organizational Communication"),
        ("She gave an amorphous answer to my question.", "She provided a vague answer to my question.", "Dialogue")
    ],
    "austere": [
        ("The austere landscape of the desert was breathtaking.", "The stark landscape of the desert was breathtaking.", "Nature Description"),
        ("He chose an austere style for his office.", "He opted for a minimalistic style for his office.", "Interior Design"),
        ("The regime imposed austere measures.", "The regime imposed strict measures.", "Government Policy"),
        ("Austere monks lead a life of self-denial.", "Ascetic monks lead a life of self-denial.", "Religious Life"),
        ("Her austere appearance intimidated newcomers.", "Her severe appearance intimidated newcomers.", "Social Interaction")
    ],
    "belie": [
        ("His smile belied his true feelings.", "His smile masked his true feelings.", "Emotional Disguise"),
        ("The data belie the assumption of progress.", "The data contradict the assumption of progress.", "Data Analysis"),
        ("Her calm voice belied the urgency of the situation.", "Her calm voice masked the urgency of the situation.", "Crisis Management"),
        ("The simplicity of the design belies its complexity.", "The simplicity of the design conceals its complexity.", "Product Design"),
        ("The exterior belied the interior's luxury.", "The plain exterior concealed the interior's luxury.", "Real Estate")
    ],
    "capricious": [
        ("The judge's capricious rulings frustrated both parties.", "The judge's erratic rulings frustrated both parties.", "Judicial Proceedings"),
        ("Weather in this region is particularly capricious.", "Weather in this region is particularly erratic.", "Weather"),
        ("Her capricious moods are difficult to manage.", "Her whimsical moods are difficult to manage.", "Personal Relationships"),
        ("Capricious winds made sailing difficult.", "Erratic winds made sailing difficult.", "Sailing"),
        ("He was known for his capricious nature.", "He was known for his fickle nature.", "Personality Traits")
    ],
    "cerebral": [
        ("The debate was a cerebral battle of wits.", "The debate was an intellectual battle of wits.", "Academic"),
        ("She enjoys cerebral films that make you think.", "She enjoys intellectual films that stimulate thought.", "Entertainment"),
        ("His interests are mainly cerebral rather than physical.", "His interests are mainly intellectual rather than physical.", "Personal Preference"),
        ("Cerebral conversations can be quite exhausting.", "Mentally stimulating conversations can be quite exhausting.", "Social Interaction"),
        ("The cerebral nature of the course discouraged many students.", "The intellectual nature of the course discouraged many students.", "Education")
    ],
    "congenial": [
        ("He found the work environment to be very congenial.", "He found the work environment to be very pleasant.", "Workplace"),
        ("They enjoyed a congenial evening with friends.", "They enjoyed a delightful evening with friends.", "Social Event"),
        ("Her congenial personality made her popular.", "Her amiable personality made her popular.", "Personality"),
        ("A congenial atmosphere encourages creativity.", "A friendly atmosphere encourages creativity.", "Work Environment"),
        ("We need to create a more congenial setting for discussions.", "We need to create a more hospitable setting for discussions.", "Meeting")
    ],
    "conspicuous": [
        ("His conspicuous absence was noted by all.", "His noticeable absence was noted by all.", "Event"),
        ("She wore a conspicuous red dress to the party.", "She wore an eye-catching red dress to the party.", "Social Gathering"),
        ("The error was conspicuous in the document.", "The error was obvious in the document.", "Work"),
        ("He tried to avoid being conspicuous at the meeting.", "He tried to avoid being prominent at the meeting.", "Corporate Strategy"),
        ("Conspicuous consumption is common among the wealthy.", "Ostentatious consumption is common among the wealthy.", "Economic Behavior")
    ],
    "cursory": [
        ("He gave a cursory glance at the document.", "He gave a brief glance at the document.", "Review Process"),
        ("The inspection was cursory and missed many defects.", "The inspection was superficial and missed many defects.", "Quality Control"),
        ("A cursory examination was conducted.", "A quick examination was conducted.", "Medical"),
        ("Cursory preparations will not be enough.", "Hasty preparations will not be enough.", "Event Planning"),
        ("His knowledge of the topic is only cursory.", "His knowledge of the topic is only superficial.", "Education")
    ],
    "daunting": [
        ("The task was daunting to the new employees.", "The task was intimidating to the new employees.", "Work Challenge"),
        ("Climbing the mountain is a daunting challenge.", "Climbing the mountain is a formidable challenge.", "Adventure"),
        ("Facing the audience was daunting.", "Facing the audience was discouraging.", "Public Speaking"),
        ("The prospect of studying abroad seemed daunting.", "The prospect of studying abroad seemed overwhelming.", "Education"),
        ("The daunting instructions confused everyone.", "The overwhelming instructions confused everyone.", "Manual Guide")
    ],
    "deify": [
        ("Many ancient cultures would deify their leaders, treating them as gods.", "Many ancient cultures would idolize their leaders, treating them as gods.", "Historical"),
        ("Fans often deify celebrities, forgetting they are human too.", "Fans often glorify celebrities, forgetting they are human too.", "Celebrity Culture"),
        ("The poet's ability to deify the mundane is truly remarkable.", "The poet's ability to exalt the mundane is truly remarkable.", "Literature"),
        ("In his hometown, he was deified for his heroic actions.", "In his hometown, he was venerated for his heroic actions.", "Local Heroism"),
        ("The practice to deify concepts like freedom often leads to intense debates.", "The practice to elevate concepts like freedom often leads to intense debates.", "Political Discourse")
    ],
    "didactic": [
        ("The novel has a didactic tone that aims to teach rather than entertain.", "The novel has an instructive tone that aims to educate rather than entertain.", "Literature"),
        ("His lectures are highly didactic, filled with moral lessons.", "His lectures are highly educational, filled with moral lessons.", "Academic"),
        ("She has a didactic approach to parenting, always looking for teaching moments.", "She has a pedagogical approach to parenting, always looking for teaching moments.", "Parenting"),
        ("Didactic poetry often focuses on ethical or moral instruction.", "Educational poetry often focuses on ethical or moral instruction.", "Poetry"),
        ("This documentary is didactic, yet captivating.", "This documentary is instructive, yet captivating.", "Media")
    ],
    "disseminate": [
        ("The organization aims to disseminate information about health and wellness.", "The organization aims to spread information about health and wellness.", "Health Education"),
        ("It's important to disseminate these findings to the wider community.", "It's important to distribute these findings to the wider community.", "Research"),
        ("Social media platforms are used to disseminate news quickly.", "Social media platforms are used to broadcast news quickly.", "Technology"),
        ("The teacher disseminated the worksheets to the students.", "The teacher distributed the worksheets to the students.", "Education"),
        ("Efforts to disseminate the data were met with resistance.", "Efforts to circulate the data were met with resistance.", "Data Management")
    ],
    "feasible": [
        ("It's not feasible to implement such changes overnight.", "It's not practical to implement such changes overnight.", "Business Strategy"),
        ("We need to assess whether the plan is economically feasible.", "We need to assess whether the plan is economically viable.", "Economics"),
        ("The project seemed feasible at first glance.", "The project seemed achievable at first glance.", "Project Management"),
        ("Finding a feasible solution requires more research.", "Finding a workable solution requires more research.", "Research and Development"),
        ("Is it feasible to finish the work by the deadline?", "Is it possible to finish the work by the deadline?", "Time Management")
    ],
    "flout": [
        ("He chose to flout the rules and face the consequences.", "He chose to defy the rules and face the consequences.", "Rebellion"),
        ("Many continue to flout safety guidelines despite warnings.", "Many continue to disregard safety guidelines despite warnings.", "Safety Protocols"),
        ("Flouting the law can lead to serious penalties.", "Disobeying the law can lead to serious penalties.", "Legal"),
        ("She openly flouted the company's dress code.", "She openly ignored the company's dress code.", "Workplace"),
        ("To flout tradition is to risk social ostracism.", "To spurn tradition is to risk social ostracism.", "Social Norms")
    ],
    "homogeneous": [
        ("The population of the village is fairly homogeneous.", "The population of the village is fairly uniform.", "Demographics"),
        ("Creating a homogeneous group can reduce internal conflict.", "Creating a uniform group can reduce internal conflict.", "Team Management"),
        ("The homogeneous mixture ensures that every sip tastes the same.", "The uniform mixture ensures that every sip tastes the same.", "Cooking"),
        ("Homogeneous communities may face challenges when integrating new ideas.", "Uniform communities may face challenges when integrating new ideas.", "Social Studies"),
        ("The homogeneous design of these houses lacks uniqueness.", "The uniform design of these houses lacks uniqueness.", "Architecture")
    ],
    "humdrum": [
        ("His humdrum life needed a spark of excitement.", "His monotonous life needed a spark of excitement.", "Personal"),
        ("The meeting was humdrum, with nothing new discussed.", "The meeting was dull, with nothing new discussed.", "Business"),
        ("She tried to escape the humdrum of daily routine.", "She tried to escape the tedium of daily routine.", "Lifestyle"),
        ("The humdrum task of data entry wore him down.", "The tedious task of data entry wore him down.", "Occupation"),
        ("Living in a small town can be quite humdrum.", "Living in a small town can be quite mundane.", "Rural Life")
    ],
    "insipid": [
        ("The soup was bland and insipid.", "The soup was bland and flavorless.", "Cooking"),
        ("He gave an insipid performance that didn't impress the audience.", "He gave a lackluster performance that didn't impress the audience.", "Theatre"),
        ("Most critics called the film insipid and unoriginal.", "Most critics called the film dull and unoriginal.", "Cinema"),
        ("Her insipid remarks did not add much to the discussion.", "Her vapid remarks did not add much to the discussion.", "Debate"),
        ("The lecture was insipid, causing many students to lose interest.", "The lecture was uninteresting, causing many students to lose interest.", "Education")
    ],
    "loquacious": [
        ("His loquacious nature made him a popular radio host.", "His talkative nature made him a popular radio host.", "Broadcasting"),
        ("She became particularly loquacious when discussing her hobbies.", "She became particularly chatty when discussing her hobbies.", "Social Interaction"),
        ("The loquacious guest dominated the dinner conversation.", "The garrulous guest dominated the dinner conversation.", "Social Event"),
        ("In meetings, he is loquacious, which can delay decisions.", "In meetings, he is verbose, which can delay decisions.", "Business"),
        ("Being loquacious is not always advantageous in negotiations.", "Being talkative is not always advantageous in negotiations.", "Negotiation Skills")
    ],
    "misanthropic": [
        ("His misanthropic views made him avoid social interactions.", "His antisocial views made him avoid social interactions.", "Personality"),
        ("The novelist's misanthropic protagonist is hard to like.", "The novelist's misanthropic protagonist is hard to like.", "Literature"),
        ("After years of betrayal, he became quite misanthropic.", "After years of betrayal, he became quite unsociable.", "Personal Development"),
        ("Misanthropic tendencies often lead to loneliness.", "Antisocial tendencies often lead to loneliness.", "Psychology"),
        ("Her misanthropic comments during the meeting surprised everyone.", "Her unsociable comments during the meeting surprised everyone.", "Corporate Communication")
    ],
    "misnomer": [
        ("Calling it a 'peacekeeping' force is a misnomer given its aggressive tactics.", "Labeling it a 'peacekeeping' force is inaccurate given its aggressive tactics.", "Political Commentary"),
        ("The term 'jumbo shrimp' is an obvious misnomer.", "The term 'jumbo shrimp' is clearly a contradiction.", "Language"),
        ("Referring to the event as a riot is a misnomer; it was actually a peaceful protest.", "Referring to the event as a riot is misleading; it was actually a peaceful protest.", "News Reporting"),
        ("To call this chaos a strategy would be a misnomer.", "To call this chaos a strategy would be misleading.", "Business"),
        ("It's a misnomer to call this ancient ritual a mere tradition.", "It's incorrect to call this ancient ritual a mere tradition.", "Cultural Studies")
    ],
    "negligent": [
        ("The company was sued for negligent safety practices.", "The company was sued for careless safety practices.", "Legal"),
        ("He was found negligent in not securing his passwords.", "He was found irresponsible in not securing his passwords.", "Cybersecurity"),
        ("Negligent driving can lead to severe accidents.", "Reckless driving can lead to severe accidents.", "Road Safety"),
        ("The landlord was negligent in dealing with the building's issues.", "The landlord was neglectful in dealing with the building's issues.", "Real Estate"),
        ("Their negligent attitude towards data privacy raised concerns.", "Their lax attitude towards data privacy raised concerns.", "Privacy Policy")
    ],
    "obsequious": [
        ("His obsequious behavior at work earned him no respect.", "His sycophantic behavior at work earned him no respect.", "Workplace"),
        ("She disliked the obsequious praise heaped upon her by her aides.", "She disliked the fawning praise heaped upon her by her aides.", "Politics"),
        ("The waiter's obsequious manner was too much for the diners.", "The waiter's servile manner was too much for the diners.", "Hospitality"),
        ("Obsequious fans can be overwhelming for celebrities.", "Fawning fans can be overwhelming for celebrities.", "Celebrity Life"),
        ("His obsequious tone when talking to superiors was noticeable.", "His ingratiating tone when talking to superiors was noticeable.", "Corporate Culture")
    ],
    "placate": [
        ("They tried to placate the angry customers with free coupons.", "They tried to appease the angry customers with free coupons.", "Customer Service"),
        ("He gave a reassuring speech to placate investors.", "He gave a calming speech to appease investors.", "Finance"),
        ("The administration took steps to placate protesters.", "The administration took steps to calm protesters.", "Government Policy"),
        ("Trying to placate her with gifts was not a genuine solution.", "Trying to mollify her with gifts was not a genuine solution.", "Personal Relationships"),
        ("The coach's decision was just an attempt to placate the fans.", "The coach's decision was just an attempt to pacify the fans.", "Sports Management")
    ],
    "proclivity": [
        ("He has a proclivity for dramatic entrances.", "He has a penchant for dramatic entrances.", "Personal Characteristics"),
        ("Her proclivity for meticulous planning makes her an excellent event organizer.", "Her inclination for meticulous planning makes her an excellent event organizer.", "Occupational Skill"),
        ("There's a noticeable proclivity in the data towards positive results.", "There's a noticeable tendency in the data towards positive results.", "Statistics"),
        ("Young children show a proclivity to imitate their parents.", "Young children show a propensity to imitate their parents.", "Child Development"),
        ("He displayed a proclivity for risky investments.", "He displayed a predilection for risky investments.", "Financial Behavior")
    ],
    "puerile": [
        ("His puerile behavior at the formal dinner was embarrassing.", "His childish behavior at the formal dinner was embarrassing.", "Social Etiquette"),
        ("The debate turned into a puerile argument with no substance.", "The debate turned into a juvenile argument with no substance.", "Public Speaking"),
        ("She dismissed his concerns as puerile.", "She dismissed his concerns as immature.", "Personal Interaction"),
        ("The movie was criticized for its puerile sense of humor.", "The movie was criticized for its immature sense of humor.", "Film Review"),
        ("Engaging in puerile antics, the students disrupted the class.", "Engaging in childish antics, the students disrupted the class.", "Education")
    ],
    "quixotic": [
        ("His quixotic quest for hidden treasure was deemed unrealistic.", "His idealistic quest for hidden treasure was deemed unrealistic.", "Adventure"),
        ("She was known for her quixotic ideas about world peace.", "She was known for her utopian ideas about world peace.", "Idealism"),
        ("The project was a quixotic endeavor that ultimately failed.", "The project was an impractical endeavor that ultimately failed.", "Business Projects"),
        ("Adopting such a quixotic approach in this serious matter can be risky.", "Adopting such a visionary approach in this serious matter can be risky.", "Strategy"),
        ("Their quixotic campaign against the powerful corporation seemed doomed.", "Their romantic campaign against the powerful corporation seemed doomed.", "Activism")
    ],
    "spendthrift": [
        ("He was a notorious spendthrift, wasting all his earnings.", "He was a notorious wastrel, squandering all his earnings.", "Financial Behavior"),
        ("Her spendthrift habits led to a pile of unnecessary debt.", "Her profligate habits led to a pile of unnecessary debt.", "Personal Finance"),
        ("As a spendthrift, he had difficulty saving any money.", "As a big spender, he had difficulty saving any money.", "Economic Planning"),
        ("The family worried about her spendthrift ways affecting her future.", "The family worried about her extravagant ways affecting her future.", "Family Concerns"),
        ("Spendthrift tendencies often lead to financial instability.", "Extravagant tendencies often lead to financial instability.", "Financial Advice")
    ],
    "taciturn": [
        ("His taciturn nature often made him seem unapproachable.", "His reticent nature often made him seem unapproachable.", "Personality Traits"),
        ("She was unusually taciturn today, speaking very little.", "She was unusually reserved today, speaking very little.", "Behavioral Observation"),
        ("The taciturn old man shared little about his past.", "The laconic old man shared little about his past.", "Character Description"),
        ("Being taciturn is sometimes mistaken for rudeness.", "Being uncommunicative is sometimes mistaken for rudeness.", "Social Misunderstanding"),
        ("In meetings, he is taciturn, preferring to listen rather than speak.", "In meetings, he is silent, preferring to listen rather than speak.", "Workplace Dynamics")
    ],
    "wary": [
        ("Be wary of offers that seem too good to be true.", "Be cautious of offers that seem too good to be true.", "Advice"),
        ("She was wary of making any quick decisions.", "She was circumspect about making any quick decisions.", "Decision Making"),
        ("Investors are wary in the current volatile market.", "Investors are guarded in the current volatile market.", "Finance"),
        ("He remained wary around the unfamiliar guests.", "He remained suspicious around the unfamiliar guests.", "Social Interaction"),
        ("Cats are naturally wary of water.", "Cats are naturally distrustful of water.", "Animal Behavior")
    ]
}

# %% [markdown]
# # libs

# %%
import csv

# %% [markdown]
# # Code

# %%
# Define the CSV file name
filename = "gre_dataset_group1.csv"

# Writing to csv file
with open(filename, 'w', newline='') as csvfile:
    # Creating a csv dict writer object
    fieldnames = ['Word', 'Sentence', 'Paraphrase', 'Context']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    # Writing headers (field names)
    writer.writeheader()

    # Writing data rows
    for word, entries in data.items():
        for sentence, paraphrase, context in entries:
            writer.writerow({'Word': word, 'Sentence': sentence, 'Paraphrase': paraphrase, 'Context': context})

print(f"CSV file '{filename}' has been created successfully.")
# Out:
# CSV file 'gre_dataset_group1.csv' has been created successfully.
